# %% [markdown]
# # Madi Joyal
#
# ## Research question/interests
#
# Research Question: Is there a connection between parental education status and GPA? I chose this question because my family hasn't traditionally valued education - I am the first in my family to go to post-secondary schooling. If there is a connection, I'd love to go into more depth and see if there is a discrepancy between how much mother's and father's education statuses influence GPA.
#
# I also want to know if there is a discrepanc y between mother's and father's education statuses
#
#
# is there a connection between parental education status and alcohol consumption? I chose this question because I am the first in my family to get their undergraduate degree. I want to know whether a low parental education status gives their children a higher likelihood of drinking alcohol during adolescence. I'd also love to explore whether mothers' or fathers' education statuses influence their child's alcohol consumption more.
#
# Does divorce during childhood increase the likelihood of alcohol consumption in highschool?
#
# I more specifically want to look at whether mother's or father's education statuses infleuc
#
#
# Research Question: Is there a connection between parental education status and GPA?
# amount of failures?

# %%
# My Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
#Task 1
## First I am merging my two datasets from the two classes interviewed for this dataset. And then, I am taking a broad look at all of my data.
df1 = pd.read_csv('../data/raw/student-mat.csv')
df2 = pd.read_csv('../data/raw/student-por.csv')
df = pd.merge(df1,df2, how = "outer")
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1044 non-null   int64
#  1   school      1044 non-null   object
#  2   sex         1044 non-null   object
#  3   age         1044 non-null   int64
#  4   address     1044 non-null   object
#  5   famsize     1044 non-null   object
#  6   Pstatus     1044 non-null   object
#  7   Medu        1044 non-null   int64
#  8   Fedu        1044 non-null   int64
#  9   Mjob        1044 non-null   object
#  10  Fjob        1044 non-null   object
#  11  reason      1044 non-null   object
#  12  guardian    1044 non-null   object
#  13  traveltime  1044 non-null   int64
#  14  studytime   1044 non-null   int64
#  15  failures    1044 non-null   int64
#  16  schoolsup   1044 non-null   object
#  17  famsup      1044 non-null   object
#  18  paid        1044 non-null   object
# ...

# %%
#create the correlation matrix heat map
#df['Pstatus'] = df[''].astype(str).astype(int)
replacer = {'A': 1, 'T': 2}
cols = df.columns[df.dtypes == 'object']
# Replace Values in those Columns
df[cols] = df[cols].replace(replacer)


## Correlation Matrix Heat Map - due to the high number of columns, I removed columns I was sure
nowdf = df.copy().drop(['nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout'], axis=1).dropna(axis=0)
plt.figure(figsize=(14,12))
sns.heatmap(nowdf.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %%
df.describe()
# Out:
#         Unnamed: 0          age         Medu         Fedu   traveltime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean    276.949234    16.726054     2.603448     2.387931     1.522989
# std     174.819941     1.239975     1.124907     1.099938     0.731727
# min       1.000000    15.000000     0.000000     0.000000     1.000000
# 25%     131.000000    16.000000     2.000000     1.000000     1.000000
# 50%     261.500000    17.000000     3.000000     2.000000     1.000000
# 75%     392.000000    18.000000     4.000000     3.000000     2.000000
# max     649.000000    22.000000     4.000000     4.000000     4.000000
#
#          studytime     failures       famrel     freetime        goout  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      1.970307     0.264368     3.935824     3.201149     3.156130
# std       0.834353     0.656142     0.933401     1.031507     1.152575
# ...

# %%
df.shape
# Out:
# (1044, 34)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.nunique(axis=0)
# Out:
# Unnamed: 0    649
# school          2
# sex             2
# age             8
# address         2
# famsize         2
# Pstatus         2
# Medu            5
# Fedu            5
# Mjob            5
# Fjob            5
# reason          4
# guardian        3
# traveltime      4
# studytime       4
# failures        4
# schoolsup       2
# famsup          2
# paid            2
# activities      2
# nursery         2
# higher          2
# internet        2
# romantic        2
# famrel          5
# freetime        5
# goout           5
# Dalc            5
# Walc            5
# health          5
# absences       35
# G1             18
# G2             17
# G3             19
# dtype: int64

# %%
#Looking at histograms of all the numerical columns within my dataset.
#These visual representations helped me understand my data and helped me find outliers later in the EDA process.
hist = df.hist(bins=10,figsize =(20,15))

# %%
#Cleaning my Dataset




##Removing Outliers
df_cleaned = df.copy()
df_cleaned = df_cleaned[df_cleaned['age'].between(15, 19)]
df_cleaned = df_cleaned[df_cleaned['absences'] < 20]
df_cleaned = df_cleaned[df_cleaned['studytime'] < 60]
df_cleaned = df_cleaned[df_cleaned['Medu'] > 0]
df_cleaned = df_cleaned[df_cleaned['Fedu'] > 0]

# Replacing Values (Might not be needed) - Replacing A (apart) for 1 and T (together) for 2 in Pstatus. Having these values as integers will be helpful further into the process
replacer = {'A': 1, 'T': 2}
cols = df.columns[df.dtypes == 'object']
df[cols] = df[cols].replace(replacer)
df_cleaned.shape
df_cleaned

#Prior to cleaning, my dataset had 1044 rows and 54 columns. Now it has 1004 rows and 54 columns.
# Out:
#       Unnamed: 0 school sex  age address famsize  Pstatus  Medu  Fedu  \
# 0              1     GP   F   18       U     GT3        1     4     4
# 1              2     GP   F   17       U     GT3        2     1     1
# 2              3     GP   F   15       U     LE3        2     1     1
# 3              4     GP   F   15       U     GT3        2     4     2
# 4              5     GP   F   16       U     GT3        2     3     3
# ...          ...    ...  ..  ...     ...     ...      ...   ...   ...
# 1039         645     MS   F   19       R     GT3        2     2     3
# 1040         646     MS   F   18       U     LE3        2     3     1
# 1041         647     MS   F   18       U     GT3        2     1     1
# 1042         648     MS   M   17       U     LE3        2     3     1
# 1043         649     MS   M   18       R     LE3        2     3     2
#
#           Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  \
# ...

# %%
##Checking my dataset for null values

df_cleaned = df_cleaned.dropna(axis=0)
df_cleaned.shape

#Since the row and column numbers stayed the same, we know that there are no null values in this dataset.
# Out:
# (988, 34)

# %%
#Focusing on one variable at a time: Workday alcohol consumption (Dalc)

sns.countplot(data = df_cleaned, x = 'Dalc').set(title= "Countplot for Workday Alcohol Consumption")
# Out:
# [Text(0.5, 1.0, 'Countplot for Workday Alcohol Consumption')]

# %%
#This plot gives me an idea of how many students drink during a less socially appropriate time, during the work week.

# %%
histo1 = df_cleaned['Fedu'].plot(kind='hist', bins=10, facecolor='red',edgecolor='red')
histo2 = df_cleaned['Medu'].plot(kind='hist', bins=20, facecolor='blue',edgecolor='blue')
histo1, histo2.set(title = "Comparing Fedu to Medu via Histogram", xlabel = "Education Level")
# Out:
# (<AxesSubplot:title={'center':'Comparing Fedu to Medu via Histogram'}, xlabel='Education Level', ylabel='Frequency'>,
#  [Text(0.5, 1.0, 'Comparing Fedu to Medu via Histogram'),
#   Text(0.5, 0, 'Education Level')])

# %%
##From this Histogram, you can see that the mothers have a higher education level on average than the fathers used in this dataset.
##This dataset also shows me that those with 0 level education are outliers within this dataset. I will remove them in my cleaning step.

# %%
#Focusing on one variable: Age of students (age)
#AgeBox = df_cleaned.boxenplot('Dalc').set(title='Number of Students at Each Age')
#AgeBox

sns.jointplot(data=df_cleaned, x="Fedu", y="Dalc", kind='hex')

#histo1 = df_cleaned['Fedu'].plot(kind='cat', facecolor='red',edgecolor='red')

# %%
sns.violinplot(data=df_cleaned, x="Fedu", y="Walc", hue = 'Pstatus')
# Out:
# <AxesSubplot:xlabel='Fedu', ylabel='Walc'>

# %%
# { “scatter” | “kde” | “hist” | “hex” | “reg” | “resid” }
sns.jointplot(x='Fedu',y='Walc', data=df_cleaned, kind='hist')
plt.xlabel("Fedu")
plt.ylabel("Alc")

sns.jointplot(x='Medu',y='Walc', data=df_cleaned, kind='hex')
plt.xlabel("Medu")
plt.ylabel("Walc")
# Out:
# Text(22.0, 0.5, 'Walc')

# %%
sns.jointplot(x='Fedu',y='Walc', data=df_cleaned, kind='hist')

# %%
MeduCount = sns.countplot(data=df_cleaned, y="Medu", palette = "bright").set(title='Number of Mothers at each education status')

# %%
# The numeric system for mother and father education status is: 1 = primary education, 2 = 5th to 9th grade, 3 = secondary education, and 4 = Higher Education

# %%
#Task2

# %%
# My Import Libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading my Data

df1 = pd.read_csv('../data/raw/student-mat.csv')
df2 = pd.read_csv('../data/raw/student-por.csv')
df = pd.merge(df1,df2, how = "outer")
df.info()
df.describe()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1044 non-null   int64
#  1   school      1044 non-null   object
#  2   sex         1044 non-null   object
#  3   age         1044 non-null   int64
#  4   address     1044 non-null   object
#  5   famsize     1044 non-null   object
#  6   Pstatus     1044 non-null   object
#  7   Medu        1044 non-null   int64
#  8   Fedu        1044 non-null   int64
#  9   Mjob        1044 non-null   object
#  10  Fjob        1044 non-null   object
#  11  reason      1044 non-null   object
#  12  guardian    1044 non-null   object
#  13  traveltime  1044 non-null   int64
#  14  studytime   1044 non-null   int64
#  15  failures    1044 non-null   int64
#  16  schoolsup   1044 non-null   object
#  17  famsup      1044 non-null   object
#  18  paid        1044 non-null   object
# ...

# %%
df1 = pd.read_csv('../data/raw/student-mat.csv')
df2 = pd.read_csv('../data/raw/student-por.csv')
df= pd.merge(df1,df2, how = "outer")
df
# Out:
#       Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              1     GP   F   18       U     GT3       A     4     4
# 1              2     GP   F   17       U     GT3       T     1     1
# 2              3     GP   F   15       U     LE3       T     1     1
# 3              4     GP   F   15       U     GT3       T     4     2
# 4              5     GP   F   16       U     GT3       T     3     3
# ...          ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039         645     MS   F   19       R     GT3       T     2     3
# 1040         646     MS   F   18       U     LE3       T     3     1
# 1041         647     MS   F   18       U     GT3       T     1     1
# 1042         648     MS   M   17       U     LE3       T     3     1
# 1043         649     MS   M   18       R     LE3       T     3     2
#
#           Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  \
# ...

# %%
#I am ensuring that there are no duplicates from merging the math and portuguese class datasets

if len(df[df.duplicated()]) > 0:
    print("Number of duplicated entries: ", len(df[df.duplicated()]))
    print(df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head())
else:
    print("Number duplicated entries found")
# Out:
# Number duplicated entries found

# %%
#I am removing the columns that are irrelevant to my research questions:
cleandf = df.copy().drop(['school','sex', 'famsup', 'age', 'guardian', 'address', 'famsize', 'famrel', 'freetime', 'goout', 'Mjob', 'Fjob', 'reason', 'G1', 'G2', 'G3', 'romantic', 'internet', 'higher', 'nursery', 'activities', 'paid', 'absences', 'health', 'traveltime', 'studytime', 'failures', 'schoolsup'], axis=1).dropna(axis=0)
cleandf
# Out:
#       Unnamed: 0 Pstatus  Medu  Fedu  Dalc  Walc
# 0              1       A     4     4     1     1
# 1              2       T     1     1     1     1
# 2              3       T     1     1     2     3
# 3              4       T     4     2     1     1
# 4              5       T     3     3     1     2
# ...          ...     ...   ...   ...   ...   ...
# 1039         645       T     2     3     1     2
# 1040         646       T     3     1     1     1
# 1041         647       T     1     1     1     1
# 1042         648       T     3     1     3     4
# 1043         649       T     3     2     3     4
#
# [1044 rows x 6 columns]

# %%
# I am now renaming the "Unnamed: 0" column to "Student#" as the previous name says nothing about the column.

cleandf = cleandf.rename(columns={'Unnamed: 0':'StudentNum'})
cleandf
# Out:
#       StudentNum Pstatus  Medu  Fedu  Dalc  Walc
# 0              1       A     4     4     1     1
# 1              2       T     1     1     1     1
# 2              3       T     1     1     2     3
# 3              4       T     4     2     1     1
# 4              5       T     3     3     1     2
# ...          ...     ...   ...   ...   ...   ...
# 1039         645       T     2     3     1     2
# 1040         646       T     3     1     1     1
# 1041         647       T     1     1     1     1
# 1042         648       T     3     1     3     4
# 1043         649       T     3     2     3     4
#
# [1044 rows x 6 columns]

# %%
#I am creating two columns:
## One column containing the mean of Medu (maternal education) and Fedu (paternal education). 
### This new column = Parental Education (Pedu)

## The other new column containing the mean of the values for workday alcohol consumption (Dalc) and weekend alcohol consumption (Walc).
#This new column = Alcohol Consumption (Alc)

cleandf['Pedu'] = ((df.Medu.astype(int) + df.Fedu.astype(int))*(1/2))
cleandf['Alc'] = ((df.Walc*(1/2)) + (df.Dalc*(1/2)))
cleandf
# Out:
#       StudentNum Pstatus  Medu  Fedu  Dalc  Walc  Pedu  Alc
# 0              1       A     4     4     1     1   4.0  1.0
# 1              2       T     1     1     1     1   1.0  1.0
# 2              3       T     1     1     2     3   1.0  2.5
# 3              4       T     4     2     1     1   3.0  1.0
# 4              5       T     3     3     1     2   3.0  1.5
# ...          ...     ...   ...   ...   ...   ...   ...  ...
# 1039         645       T     2     3     1     2   2.5  1.5
# 1040         646       T     3     1     1     1   2.0  1.0
# 1041         647       T     1     1     1     1   1.0  1.0
# 1042         648       T     3     1     3     4   2.0  3.5
# 1043         649       T     3     2     3     4   2.5  3.5
#
# [1044 rows x 8 columns]

# %%
#Task 3

#sns.histo(cleandf, x_vars =["Pstatus"], y_vars = ["Alc"])

# %%
histo1 = df_cleaned['Fedu'].plot(kind='hist', bins=10, facecolor='red',edgecolor='red')
histo2 = df_cleaned['Medu'].plot(kind='hist', bins=20, facecolor='blue',edgecolor='blue')
histo1, histo2.set(title = "Comparing Fedu to Medu via Histogram", xlabel = "Education Level")
# Out:
# (<AxesSubplot:title={'center':'Comparing Fedu to Medu via Histogram'}, xlabel='Education Level', ylabel='Frequency'>,
#  [Text(0.5, 1.0, 'Comparing Fedu to Medu via Histogram'),
#   Text(0.5, 0, 'Education Level')])

# %%
cleandf.groupby('Fedu').count()
# Out:
#       StudentNum  Pstatus  Medu  Dalc  Walc  Pedu  Alc
# Fedu
# 0              9        9     9     9     9     9    9
# 1            256      256   256   256   256   256  256
# 2            324      324   324   324   324   324  324
# 3            231      231   231   231   231   231  231
# 4            224      224   224   224   224   224  224

# %%
#Include a doc string in your method chain says Foosi

# %%
#Method Chaining

# %%
sns.catplot(data=cleandf, x="Fedu", y='Walc', palette = 'bright').set(title='Number of Mothers at each education status')
# Out:
# <ipython-input-371-d3732c7048f3>:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(data=cleandf, x="Fedu", y='Walc', palette = 'bright').set(title='Number of Mothers at each education status')

# %%
sns.stripplot(data=cleandf, x="Pedu", y='Dalc', palette = 'bright', hue = 'Pstatus', size = 1)
# Out:
# <AxesSubplot:xlabel='Pedu', ylabel='Dalc'>

# %%
cleandf.info('Alc')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 1043
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentNum  1044 non-null   int64
#  1   Pstatus     1044 non-null   object
#  2   Medu        1044 non-null   int64
#  3   Fedu        1044 non-null   int64
#  4   Dalc        1044 non-null   int64
#  5   Walc        1044 non-null   int64
#  6   Pedu        1044 non-null   float64
#  7   Alc         1044 non-null   float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 73.4+ KB
